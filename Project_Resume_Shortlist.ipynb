# %%
import cv2
import pytesseract
import numpy as np
import os
from pytesseract import Output
import re
from re import search
import pandas as pd

# %%
d=os.listdir(r'C:\Users\delbi\Videos\Computer vision\opencv\project\resumes')
d
# Out:
# ['2020-12-data-analyst-resume-sample-791x1024.jpeg',
#  'data-analyst-resume-intermediate.jpeg',
#  'dataanalyst.jpeg',
#  'pic.jpeg',
#  'pic2.jpeg',
#  'senior-software-tester-1588661306-pdf.jpeg',
#  'software-testing-it-traditional-1.jpeg',
#  'web-developer-resume-sample.jpeg']

# %%
for i in d:
  img_path=os.path.join(r'C:\Users\delbi\Videos\Computer vision\opencv\project\resumes',i)
  img=cv2.imread(img_path,cv2.IMREAD_GRAYSCALE)
  img_resized=cv2.resize(img,(900,900))
  cv2.imshow('image',img_resized)
  cv2.waitKey()
  cv2.destroyAllWindows()

# %%
pytesseract.pytesseract.tesseract_cmd = r"C:\Program Files (x86)\Tesseract-OCR\tesseract.exe"

# %%
text=pytesseract.image_to_string(img_resized)

# %%
text
# Out:
# 'HTMLS:\n\napr ae\niil\n\n2\n\nHP\n\naL\n\nAdobe Creative Suite\n\n!\n\nx\n\nML\n\nINTERESTS\n\n[{) Machine Learning\n\n(2) video Games\n\n"SS Robotics\n\nJonathan Smith\n\nSenior Web Developer\n\nInnovative, task-driven p I with 8+ years of experience in web design and pment acre\ndiverse incu rd of 3 tly identifying and providing thi\ntechnological gh ingenious innovation, Proficient in developing datab:\ncreating user intrlaces ting codes, troubleshooting simple/complex issues, and\nimplementir\n\nWORK EXPERIENCE\n\nWeb Developer\n\nPrecious Technology Co.\n\n© Design and establish user-friendly websites, including optimized check-out page, resulting in a 25%\nIncrease in user clicks and subsequently 33% in customer purchases.\n\n= Provide adequate training to 60+ staff members and 20+ junior web developers in intemal web,\nfunctions, including steps on how to make minor updates/changes independently.\n\n© Establish an interactive and dynamic website that guarantees high traffic, 
# ...

# %%
def check_resume(resume,job):
    res=re.sub(r'[^a-zA-Z]','',resume).lower()
    # print(res)
    for i in job:
        if ''.join(i.lower().split()) in res:
            print('sel')
        else:
            print('rej')

# %%
job=['data analyst','data analysis','data analytics','data science']
check_resume(text,job)
# Out:
# rej
# rej
# rej
# rej

# %%
key_words=['data analyst','data analysis','data analytics','data science']
for i in sen:
    if search(i,sen):
        print('Resume Selected')
    else:
        print('Resume Rejected')
# Out:
# Resume Selected
# Resume Selected
# Resume Selected
# Resume Selected
# Resume Selected
# Resume Selected
# Resume Selected
# Resume Selected
# Resume Selected
# Resume Selected
# Resume Selected
# Resume Selected
# Resume Selected
# Resume Selected
# Resume Selected
# Resume Selected
# Resume Selected
# Resume Selected
# Resume Selected
# Resume Selected
# Resume Selected
# Resume Selected
# Resume Selected
# Resume Selected
# Resume Selected
# Resume Selected
# Resume Selected
# Resume Selected
# Resume Selected
# Resume Selected
# Resume Selected
# Resume Selected
# Resume Selected
# Resume Selected
# Resume Selected
# Resume Selected
# Resume Selected
# Resume Selected
# Resume Selected
# Resume Selected
# Resume Selected
# Resume Selected
# Resume Selected
# Resume Selected
# Resume Selected
# Resume Selected
# Resume Selected
# Resume Selected
# Resume Selected
# Resume Selected
# Resume Selected
# Resume Selected
# Resume Selected
# Resume Selected
# Resume Selected
# ...

# %%
key_words=['data analyst','data analysis','business analy','data analytics','data science']
for i in key_words:
    if i in sen:
        print('f')
# Out:
# f

# %%
key_words=['data analyst','data analysis','data analytics','data science']
for i in key_words:
    if search(i,sen):
        print('Resume Selected')
    else:
        print('Resume Rejected')
# Out:
# Resume Rejected
# Resume Selected
# Resume Rejected
# Resume Rejected
